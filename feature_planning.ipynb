# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy.stats import linregress
import ast

# %% [markdown]
# I am going to flesh out the features for the 'matches' table. I will start off by selecting just a couple of obvious ones, and then I will go back over things and get more features.
#
# I will start by looking at the "events" table and aggregating by the matchId identifier and joining these juicy stats onto the match table.

# %%
events = pd.read_csv('data/events_England.csv')

# %% [markdown]
# ## About this file
#
# This dataset describes all the events that occur during each match. Each event refers to a ball touch and contains the following information:
#
# - **eventId**: the identifier of the event's type. Each eventId is associated with an event name.
# - **eventName**: the name of the event's type (pass, foul, shot, duel, free kick, offside, or touch).
# - **subEventId**: the identifier of the subevent's type.
# - **subEventName**: the name of the subevent's type, associated with different event types.
# - **tags**: a list of event tags providing additional information about the event (e.g., accurate).
# - **eventSec**: the time the event occurs (in seconds since the beginning of the current half).
# - **id**: a unique identifier of the event.
# - **matchId**: the identifier of the match, linked to "wyId" in the match dataset.
# - **matchPeriod**: the period of the match ("1H", "2H", "E1", "E2", or "P").
# - **playerId**: the identifier of the player who generated the event, linked to "wyId" in a player dataset.
# - **positions**: the origin and destination positions associated with the event as (x, y) coordinates.
# - **teamId**: the identifier of the player's team, linked to "wyId" in the team dataset.
# - **tagsList**: same information as the tags column, except in list format.
# - **pos_orig_x**: from the positions column, origin in x-axis.
# - **pos_orig_y**: from the positions column, origin in y-axis.
# - **pos_dest_x**: from the positions column, destination in x-axis.
# - **pos_dest_y**: from the positions column, destination in y-axis.

# %%
events.head()
# Out:
#    eventId subEventName            tags  playerId  \
# 0        8  Simple pass  [{'id': 1801}]     25413
# 1        8    High pass  [{'id': 1801}]    370224
# 2        8    Head pass  [{'id': 1801}]      3319
# 3        8    Head pass  [{'id': 1801}]    120339
# 4        8  Simple pass  [{'id': 1801}]    167145
#
#                                   positions  matchId eventName  teamId  \
# 0  [{'y': 49, 'x': 49}, {'y': 78, 'x': 31}]  2499719      Pass    1609
# 1  [{'y': 78, 'x': 31}, {'y': 75, 'x': 51}]  2499719      Pass    1609
# 2  [{'y': 75, 'x': 51}, {'y': 71, 'x': 35}]  2499719      Pass    1609
# 3  [{'y': 71, 'x': 35}, {'y': 95, 'x': 41}]  2499719      Pass    1609
# 4  [{'y': 95, 'x': 41}, {'y': 88, 'x': 72}]  2499719      Pass    1609
#
#   matchPeriod   eventSec  subEventId         id tagsList  pos_orig_y  \
# 0          1H   2.758649        85.0  177959171   [1801]          49
# 1          1H   4.946850        83.0  177959172   [1801]          78
# 2          1H   6.542188        82.0  177959173   [1801]          75
# 3          1H   8.143395        82.0  177959174   [1801]          71
# 4          1H  10.302366        85.0  177959175   [1801]          95
#
#    pos_orig_x  pos_dest_y  pos_dest_x
# 0          49          78          31
# 1          31          75          51
# 2          51          71          35
# 3          35          95          41
# 4          41          88          72

# %% [markdown]
# ### teams

# %% [markdown]
# I am updating the teamsid to be the team name already because it helps me confirm the data is correct

# %%
teams=pd.read_csv('data/teams.csv')
teams.head()
# Out:
#                   city                   name  wyId  \
# 0  Newcastle upon Tyne       Newcastle United  1613
# 1                 Vigo          Celta de Vigo   692
# 2            Barcelona               Espanyol   691
# 3      Vitoria-Gasteiz  Deportivo Alav\u00e9s   696
# 4             Valencia                Levante   695
#
#                    officialName  \
# 0           Newcastle United FC
# 1       Real Club Celta de Vigo
# 2  Reial Club Deportiu Espanyol
# 3         Deportivo Alav\u00e9s
# 4                    Levante UD
#
#                                                 area  type
# 0  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 1  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 2  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 3  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 4  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club

# %%
team_mapping=teams.set_index('wyId')['name'].to_dict()

# %%
events['teamId']=events['teamId'].map(team_mapping)

# %%
events.rename(columns={'teamId':'teamName'}, inplace=True)

# %% [markdown]
# ### tags2name

# %%
tags2name = pd.read_csv('data/tags2name.csv')

# %% [markdown]
# ##### Joining on the tag labels to the nested tagsList column

# %%
# %%time
##takes about 42 seconds to run

#getting the list values out of the string values in the tagList column
events['tagsList'] = events['tagsList'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

#explode the tagsList column because we will get the labels
exploded_events = events.explode('tagsList')

#cast to int because the column in the tags table is int
exploded_events['tagsList']=exploded_events['tagsList'].astype('Int64')

#keep the original index because I was losing this information in the merge 
exploded_events['origIndex']=exploded_events.index

#get the tag labels
exploded_merged_events=exploded_events.merge(tags2name[['Tag','Label']], left_on='tagsList', right_on='Tag', how='left')

#grouping by original index to prepare for the join back to events table
exploded_merged_events=exploded_merged_events.groupby('origIndex').agg({
   # 'tagsList': list, 
   # 'Tag': list,
    'Label': list
}).reset_index()

#joining back onto original events table
events=pd.concat([events, exploded_merged_events['Label']], axis=1)
# Out:
# CPU times: user 25.4 s, sys: 1.05 s, total: 26.5 s
# Wall time: 26.5 s

# %% [markdown]
# ##### Removing some columns that are no longer needed

# %%
events.drop(['eventId','subEventId','tagsList','positions','tags','id'], axis=1, inplace=True)

# %%
events.head(8)
# Out:
#   subEventName  playerId  matchId eventName        teamName matchPeriod  \
# 0  Simple pass     25413  2499719      Pass         Arsenal          1H
# 1    High pass    370224  2499719      Pass         Arsenal          1H
# 2    Head pass      3319  2499719      Pass         Arsenal          1H
# 3    Head pass    120339  2499719      Pass         Arsenal          1H
# 4  Simple pass    167145  2499719      Pass         Arsenal          1H
# 5  Simple pass      3319  2499719      Pass         Arsenal          1H
# 6    Head pass      8653  2499719      Pass  Leicester City          1H
# 7     Air duel      8013  2499719      Duel  Leicester City          1H
#
#     eventSec  pos_orig_y  pos_orig_x  pos_dest_y  pos_dest_x  \
# 0   2.758649          49          49          78          31
# 1   4.946850          78          31          75          51
# 2   6.542188          75          51          71          35
# 3   8.143395          71          35          95          41
# 4  10.302366          95          41          88          72
# 5  12.548934          88          72          75          77
# 6  13.961228          25          23          15          39
# 7  14.765321          15          39          20          33
#
#                   Label
# 0            [accurate]
# 1            [accurate]
# 2            [accurate]
# 3            [accurate]
# 4            [accurate]
# 5        [not accurate]
# 6            [accurate]
# 7  [lost, not accurate]

# %% [markdown]
# Number of shots in each game

# %%
events.groupby(['matchId','teamName']).agg(
    numShots=('subEventName', lambda x: (x == 'Shot').sum())
)

##I can join this onto the matches table later
# Out:
#                                 numShots
# matchId teamName
# 2499719 Arsenal                       27
#         Leicester City                 7
# 2499720 Brighton & Hove Albion         6
#         Manchester City               12
# 2499721 Burnley                        9
# ...                                  ...
# 2500096 Swansea City                  24
# 2500097 Leicester City                17
#         Tottenham Hotspur             13
# 2500098 Everton                       13
#         West Ham United               14
#
# [760 rows x 1 columns]

# %% [markdown]
# ## Matches

# %%
matches = pd.read_csv('data/matches_England.csv')

# %%
##Dropping unneeded columns columns are all either identical or they are captured within other columns

# %%
matches.drop(['status','roundId','seasonId','duration','competitionId','teamsData','team1.formation','team2.formation','team1.scoreET','team1.scoreP','team1.hasFormation','team2.scoreET','team2.scoreP','team2.hasFormation','date'], axis=1, inplace=True)

# %%
##And then dropping the subs bench info

# %%
matches.drop(['team1.formation.bench','team2.formation.bench'], axis=1, inplace=True)

# %%
#dropping venue too, but may use it at some stage on dashboards

# %%
matches.drop(['venue'], axis=1, inplace=True)

# %%
#dropping venue too, but may use it at some stage for features or for dashboards

# %%
matches.drop(['referees'], axis=1, inplace=True)

# %% [markdown]
# I want to rejig my table so that team1 columns always refer to the home team, and team2 columns refer to the away team.

# %% [markdown]
# first ill replace the teamId's with the actual team names so that I know this is working as expected

# %% [markdown]
# ### Teams

# %%
teams=pd.read_csv('data/teams.csv')
teams.head()
team_mapping=teams.set_index('wyId')['name'].to_dict()

# %%
matches['team1.teamId']=matches['team1.teamId'].map(team_mapping)
matches['team2.teamId']=matches['team2.teamId'].map(team_mapping)
matches['winner']=matches['winner'].map(team_mapping)

# %%
matches.rename(columns={'team1.teamId':'team1.teamName','team2.teamId':'team2.teamName'}, inplace=True)

# %%
matches
# Out:
#      gameweek              dateutc                winner     wyId  \
# 0          38  2018-05-13 14:00:00       AFC Bournemouth  2500089
# 1          38  2018-05-13 14:00:00        Crystal Palace  2500090
# 2          38  2018-05-13 14:00:00               Arsenal  2500091
# 3          38  2018-05-13 14:00:00             Liverpool  2500092
# 4          38  2018-05-13 14:00:00     Manchester United  2500093
# ..        ...                  ...                   ...      ...
# 375         1  2017-08-12 14:00:00               Everton  2499723
# 376         1  2017-08-12 14:00:00                   NaN  2499726
# 377         1  2017-08-12 14:00:00  West Bromwich Albion  2499728
# 378         1  2017-08-12 11:30:00                   NaN  2499727
# 379         1  2017-08-11 18:45:00               Arsenal  2499719
#
#                                              label  team1.coachId team1.side  \
# 0                 Burnley - AFC Bournemouth, 1 - 2           8880       home
# 1     Crystal Palace - West Bromwich Albion, 2 - 0           8357       home
# 2               Huddersfield Town - Arsenal, 0 - 1           7845       away
# 3        Liverpool - Brighton & Hove Albion, 4 - 0           8093       away
# 4               Manchester United - Watford, 1 - 0          93112       away
# ..                                             ...            ...        ...
# 375                    Everton - Stoke City, 1 - 0           9054       away
# 376              Southampton - Swansea City, 0 - 0         254174       home
# 377  West Bromwich Albion - AFC Bournemouth, 1 - 0           8934       away
# 378                     Watford - Liverpool, 3 - 3          14791       away
# 379                Arsenal - Leicester City, 4 - 3           7845       home
#
#              team1.teamName  team1.score  team1.scoreHT  \
# 0                   Burnley            1              1
# 1            Crystal Palace            2              0
# 2                   Arsenal            1              1
# 3    Brighton & Hove Albion            0              0
# 4                   Watford            0              0
# ..                      ...          ...            ...
# 375              Stoke City            0              0
# 376             Southampton            0              0
# 377         AFC Bournemouth            0              0
# 378               Liverpool            3              1
# 379                 Arsenal            4              2
#
#                                 team1.formation.lineup  \
# 0    [{'playerId': 9206, 'ownGoals': '0', 'redCards...
# 1    [{'playerId': 8623, 'ownGoals': '0', 'redCards...
# 2    [{'playerId': 25867, 'ownGoals': '0', 'redCard...
# 3    [{'playerId': 120, 'ownGoals': '2', 'redCards'...
# 4    [{'playerId': 68085, 'ownGoals': '0', 'redCard...
# ..                                                 ...
# 375  [{'playerId': 20450, 'ownGoals': '0', 'redCard...
# 376  [{'playerId': 20857, 'ownGoals': '0', 'redCard...
# 377  [{'playerId': 9293, 'ownGoals': '0', 'redCards...
# 378  [{'playerId': 15808, 'ownGoals': '0', 'redCard...
# 379  [{'playerId': 370224, 'ownGoals': '0', 'redCar...
#
#                          team1.formation.substitutions  team2.coachId  \
# 0    [{'playerIn': 9127, 'playerOut': 9206, 'minute...           8934
# 1    [{'playerIn': 38031, 'playerOut': 8623, 'minut...              0
# 2    [{'playerIn': 7945, 'playerOut': 25867, 'minut...          18572
# 3    [{'playerIn': 15526, 'playerOut': 120, 'minute...          14791
# 4    [{'playerIn': 8889, 'playerOut': 68085, 'minut...           3295
# ..                                                 ...            ...
# 375  [{'playerIn': 15198, 'playerOut': 20450, 'minu...         268779
# 376  [{'playerIn': 8953, 'playerOut': 20857, 'minut...         381291
# 377  [{'playerIn': 9739, 'playerOut': 9293, 'minute...         149026
# 378  [{'playerIn': 134708, 'playerOut': 15808, 'min...          71037
# 379  [{'playerIn': 26010, 'playerOut': 370224, 'min...         333782
#
#     team2.side        team2.teamName  team2.score  team2.scoreHT  \
# 0         away       AFC Bournemouth            2              0
# 1         away  West Bromwich Albion            0              0
# 2         home     Huddersfield Town            0              0
# 3         home             Liverpool            4              2
# 4         home     Manchester United            1              1
# ..         ...                   ...          ...            ...
# 375       home               Everton            1              1
# 376       away          Swansea City            0              0
# 377       home  West Bromwich Albion            1              1
# 378       home               Watford            3              2
# 379       away        Leicester City            3              2
#
#                                 team2.formation.lineup  \
# 0    [{'playerId': 259531, 'ownGoals': '0', 'redCar...
# 1    [{'playerId': 25537, 'ownGoals': '0', 'redCard...
# 2    [{'playerId': 9419, 'ownGoals': '0', 'redCards...
# 3    [{'playerId': 25747, 'ownGoals': '2', 'redCard...
# 4    [{'playerId': 7939, 'ownGoals': '0', 'redCards...
# ..                                                 ...
# 375  [{'playerId': 77546, 'ownGoals': '0', 'redCard...
# 376  [{'playerId': 77550, 'ownGoals': '0', 'redCard...
# 377  [{'playerId': 434159, 'ownGoals': '0', 'redCar...
# 378  [{'playerId': 160, 'ownGoals': '0', 'redCards'...
# 379  [{'playerId': 14763, 'ownGoals': '0', 'redCard...
#
#                          team2.formation.substitutions
# 0    [{'playerIn': 7989, 'playerOut': 259531, 'minu...
# 1    [{'playerIn': 261, 'playerOut': 25537, 'minute...
# 2    [{'playerIn': 38377, 'playerOut': 9419, 'minut...
# 3    [{'playerIn': 8140, 'playerOut': 25747, 'minut...
# 4    [{'playerIn': 8135, 'playerOut': 7939, 'minute...
# ..                                                 ...
# 375  [{'playerIn': 340, 'playerOut': 77546, 'minute...
# 376  [{'playerIn': 62344, 'playerOut': 77550, 'minu...
# 377  [{'playerIn': 447254, 'playerOut': 434159, 'mi...
# 378  [{'playerIn': 3351, 'playerOut': 160, 'minute'...
# 379  [{'playerIn': 217078, 'playerOut': 14763, 'min...
#
# [380 rows x 19 columns]

# %% [markdown]
# #### I want all home teams on the left, all the away teams on the right. And I want it labeled home and away instead of team1 and team2

# %%
home_teams1 = matches[matches['team1.side'] == 'home'].copy()

# %%
home_teams1=home_teams1[['team1.coachId',
       'team1.side', 'team1.teamName', 'team1.score', 'team1.scoreHT',
       'team1.formation.lineup', 'team1.formation.substitutions']]

# %%
home_teams1.columns=['home.coachId', 'home.side', 'home.teamName', 'home.score',
       'home.scoreHT', 'home.formation.lineup',
       'home.formation.substitutions']

# %%
home_teams2 = matches[matches['team2.side'] == 'home'].copy()

# %%
home_teams2=home_teams2[['team2.coachId', 'team2.side', 'team2.teamName', 'team2.score',
       'team2.scoreHT', 'team2.formation.lineup',
       'team2.formation.substitutions']]

# %%
home_teams2.columns=['home.coachId', 'home.side', 'home.teamName', 'home.score',
       'home.scoreHT', 'home.formation.lineup',
       'home.formation.substitutions']

# %%
home_teams=pd.concat([home_teams1, home_teams2], axis=0).sort_index()

# %% [markdown]
# Doing the same for the away teams

# %%
away_teams1 = matches[matches['team1.side'] == 'away'].copy()

away_teams1=away_teams1[['team1.coachId',
       'team1.side', 'team1.teamName', 'team1.score', 'team1.scoreHT',
       'team1.formation.lineup', 'team1.formation.substitutions']]

away_teams1.columns=['away.coachId', 'away.side', 'away.teamName', 'away.score',
       'away.scoreHT', 'away.formation.lineup',
       'away.formation.substitutions']



away_teams2 = matches[matches['team2.side'] == 'away'].copy()

away_teams2=away_teams2[['team2.coachId', 'team2.side', 'team2.teamName', 'team2.score',
       'team2.scoreHT', 'team2.formation.lineup',
       'team2.formation.substitutions']]

away_teams2.columns=['away.coachId', 'away.side', 'away.teamName', 'away.score',
       'away.scoreHT', 'away.formation.lineup',
       'away.formation.substitutions']

away_teams=pd.concat([away_teams1, away_teams2], axis=0).sort_index()

# %% [markdown]
# joining all this back onto the matches table

# %%
matches[['gameweek', 'dateutc', 'winner', 'wyId', 'label']]
# Out:
#      gameweek              dateutc                winner     wyId  \
# 0          38  2018-05-13 14:00:00       AFC Bournemouth  2500089
# 1          38  2018-05-13 14:00:00        Crystal Palace  2500090
# 2          38  2018-05-13 14:00:00               Arsenal  2500091
# 3          38  2018-05-13 14:00:00             Liverpool  2500092
# 4          38  2018-05-13 14:00:00     Manchester United  2500093
# ..        ...                  ...                   ...      ...
# 375         1  2017-08-12 14:00:00               Everton  2499723
# 376         1  2017-08-12 14:00:00                   NaN  2499726
# 377         1  2017-08-12 14:00:00  West Bromwich Albion  2499728
# 378         1  2017-08-12 11:30:00                   NaN  2499727
# 379         1  2017-08-11 18:45:00               Arsenal  2499719
#
#                                              label
# 0                 Burnley - AFC Bournemouth, 1 - 2
# 1     Crystal Palace - West Bromwich Albion, 2 - 0
# 2               Huddersfield Town - Arsenal, 0 - 1
# 3        Liverpool - Brighton & Hove Albion, 4 - 0
# 4               Manchester United - Watford, 1 - 0
# ..                                             ...
# 375                    Everton - Stoke City, 1 - 0
# 376              Southampton - Swansea City, 0 - 0
# 377  West Bromwich Albion - AFC Bournemouth, 1 - 0
# 378                     Watford - Liverpool, 3 - 3
# 379                Arsenal - Leicester City, 4 - 3
#
# [380 rows x 5 columns]

# %%
match_cols=matches[['gameweek', 'dateutc', 'winner', 'wyId', 'label']].copy()

# %%
matches=pd.concat([match_cols , home_teams, away_teams], axis = 1)

# %%
matches
# Out:
#      gameweek              dateutc                winner     wyId  \
# 0          38  2018-05-13 14:00:00       AFC Bournemouth  2500089
# 1          38  2018-05-13 14:00:00        Crystal Palace  2500090
# 2          38  2018-05-13 14:00:00               Arsenal  2500091
# 3          38  2018-05-13 14:00:00             Liverpool  2500092
# 4          38  2018-05-13 14:00:00     Manchester United  2500093
# ..        ...                  ...                   ...      ...
# 375         1  2017-08-12 14:00:00               Everton  2499723
# 376         1  2017-08-12 14:00:00                   NaN  2499726
# 377         1  2017-08-12 14:00:00  West Bromwich Albion  2499728
# 378         1  2017-08-12 11:30:00                   NaN  2499727
# 379         1  2017-08-11 18:45:00               Arsenal  2499719
#
#                                              label  home.coachId home.side  \
# 0                 Burnley - AFC Bournemouth, 1 - 2          8880      home
# 1     Crystal Palace - West Bromwich Albion, 2 - 0          8357      home
# 2               Huddersfield Town - Arsenal, 0 - 1         18572      home
# 3        Liverpool - Brighton & Hove Albion, 4 - 0         14791      home
# 4               Manchester United - Watford, 1 - 0          3295      home
# ..                                             ...           ...       ...
# 375                    Everton - Stoke City, 1 - 0        268779      home
# 376              Southampton - Swansea City, 0 - 0        254174      home
# 377  West Bromwich Albion - AFC Bournemouth, 1 - 0        149026      home
# 378                     Watford - Liverpool, 3 - 3         71037      home
# 379                Arsenal - Leicester City, 4 - 3          7845      home
#
#             home.teamName  home.score  home.scoreHT  \
# 0                 Burnley           1             1
# 1          Crystal Palace           2             0
# 2       Huddersfield Town           0             0
# 3               Liverpool           4             2
# 4       Manchester United           1             1
# ..                    ...         ...           ...
# 375               Everton           1             1
# 376           Southampton           0             0
# 377  West Bromwich Albion           1             1
# 378               Watford           3             2
# 379               Arsenal           4             2
#
#                                  home.formation.lineup  \
# 0    [{'playerId': 9206, 'ownGoals': '0', 'redCards...
# 1    [{'playerId': 8623, 'ownGoals': '0', 'redCards...
# 2    [{'playerId': 9419, 'ownGoals': '0', 'redCards...
# 3    [{'playerId': 25747, 'ownGoals': '2', 'redCard...
# 4    [{'playerId': 7939, 'ownGoals': '0', 'redCards...
# ..                                                 ...
# 375  [{'playerId': 77546, 'ownGoals': '0', 'redCard...
# 376  [{'playerId': 20857, 'ownGoals': '0', 'redCard...
# 377  [{'playerId': 434159, 'ownGoals': '0', 'redCar...
# 378  [{'playerId': 160, 'ownGoals': '0', 'redCards'...
# 379  [{'playerId': 370224, 'ownGoals': '0', 'redCar...
#
#                           home.formation.substitutions  away.coachId  \
# 0    [{'playerIn': 9127, 'playerOut': 9206, 'minute...          8934
# 1    [{'playerIn': 38031, 'playerOut': 8623, 'minut...             0
# 2    [{'playerIn': 38377, 'playerOut': 9419, 'minut...          7845
# 3    [{'playerIn': 8140, 'playerOut': 25747, 'minut...          8093
# 4    [{'playerIn': 8135, 'playerOut': 7939, 'minute...         93112
# ..                                                 ...           ...
# 375  [{'playerIn': 340, 'playerOut': 77546, 'minute...          9054
# 376  [{'playerIn': 8953, 'playerOut': 20857, 'minut...        381291
# 377  [{'playerIn': 447254, 'playerOut': 434159, 'mi...          8934
# 378  [{'playerIn': 3351, 'playerOut': 160, 'minute'...         14791
# 379  [{'playerIn': 26010, 'playerOut': 370224, 'min...        333782
#
#     away.side           away.teamName  away.score  away.scoreHT  \
# 0        away         AFC Bournemouth           2             0
# 1        away    West Bromwich Albion           0             0
# 2        away                 Arsenal           1             1
# 3        away  Brighton & Hove Albion           0             0
# 4        away                 Watford           0             0
# ..        ...                     ...         ...           ...
# 375      away              Stoke City           0             0
# 376      away            Swansea City           0             0
# 377      away         AFC Bournemouth           0             0
# 378      away               Liverpool           3             1
# 379      away          Leicester City           3             2
#
#                                  away.formation.lineup  \
# 0    [{'playerId': 259531, 'ownGoals': '0', 'redCar...
# 1    [{'playerId': 25537, 'ownGoals': '0', 'redCard...
# 2    [{'playerId': 25867, 'ownGoals': '0', 'redCard...
# 3    [{'playerId': 120, 'ownGoals': '2', 'redCards'...
# 4    [{'playerId': 68085, 'ownGoals': '0', 'redCard...
# ..                                                 ...
# 375  [{'playerId': 20450, 'ownGoals': '0', 'redCard...
# 376  [{'playerId': 77550, 'ownGoals': '0', 'redCard...
# 377  [{'playerId': 9293, 'ownGoals': '0', 'redCards...
# 378  [{'playerId': 15808, 'ownGoals': '0', 'redCard...
# 379  [{'playerId': 14763, 'ownGoals': '0', 'redCard...
#
#                           away.formation.substitutions
# 0    [{'playerIn': 7989, 'playerOut': 259531, 'minu...
# 1    [{'playerIn': 261, 'playerOut': 25537, 'minute...
# 2    [{'playerIn': 7945, 'playerOut': 25867, 'minut...
# 3    [{'playerIn': 15526, 'playerOut': 120, 'minute...
# 4    [{'playerIn': 8889, 'playerOut': 68085, 'minut...
# ..                                                 ...
# 375  [{'playerIn': 15198, 'playerOut': 20450, 'minu...
# 376  [{'playerIn': 62344, 'playerOut': 77550, 'minu...
# 377  [{'playerIn': 9739, 'playerOut': 9293, 'minute...
# 378  [{'playerIn': 134708, 'playerOut': 15808, 'min...
# 379  [{'playerIn': 217078, 'playerOut': 14763, 'min...
#
# [380 rows x 19 columns]

# %% [markdown]
# Now I will join on the data I grouped for earlier

# %%
numshots=events.groupby(['matchId','teamName']).agg(
    numShots=('subEventName', lambda x: (x == 'Shot').sum())
).reset_index()

# %%
numshots
# Out:
#      matchId                teamName  numShots
# 0    2499719                 Arsenal        27
# 1    2499719          Leicester City         7
# 2    2499720  Brighton & Hove Albion         6
# 3    2499720         Manchester City        12
# 4    2499721                 Burnley         9
# ..       ...                     ...       ...
# 755  2500096            Swansea City        24
# 756  2500097          Leicester City        17
# 757  2500097       Tottenham Hotspur        13
# 758  2500098                 Everton        13
# 759  2500098         West Ham United        14
#
# [760 rows x 3 columns]

# %%
matches=matches.merge(
    numshots, 
    how='left', 
    left_on=['wyId','home.teamName'], 
    right_on=['matchId','teamName']
).rename(columns={'numShots':'home.numShots'})

matches.drop(['matchId','teamName'], axis=1, inplace=True)

# %%
matches=matches.merge(
    numshots, 
    how='left', 
    left_on=['wyId','away.teamName'], 
    right_on=['matchId','teamName']
).rename(columns={'numShots':'away.numShots'})

matches.drop(['matchId','teamName'], axis=1, inplace=True)

# %%
#numshots[numshots['matchId'].isin([2500089,2500090])]

# %%
matches.head()
# Out:
#    gameweek              dateutc             winner     wyId  \
# 0        38  2018-05-13 14:00:00    AFC Bournemouth  2500089
# 1        38  2018-05-13 14:00:00     Crystal Palace  2500090
# 2        38  2018-05-13 14:00:00            Arsenal  2500091
# 3        38  2018-05-13 14:00:00          Liverpool  2500092
# 4        38  2018-05-13 14:00:00  Manchester United  2500093
#
#                                           label  home.coachId home.side  \
# 0              Burnley - AFC Bournemouth, 1 - 2          8880      home
# 1  Crystal Palace - West Bromwich Albion, 2 - 0          8357      home
# 2            Huddersfield Town - Arsenal, 0 - 1         18572      home
# 3     Liverpool - Brighton & Hove Albion, 4 - 0         14791      home
# 4            Manchester United - Watford, 1 - 0          3295      home
#
#        home.teamName  home.score  home.scoreHT  ...  \
# 0            Burnley           1             1  ...
# 1     Crystal Palace           2             0  ...
# 2  Huddersfield Town           0             0  ...
# 3          Liverpool           4             2  ...
# 4  Manchester United           1             1  ...
#
#                         home.formation.substitutions away.coachId  away.side  \
# 0  [{'playerIn': 9127, 'playerOut': 9206, 'minute...         8934       away
# 1  [{'playerIn': 38031, 'playerOut': 8623, 'minut...            0       away
# 2  [{'playerIn': 38377, 'playerOut': 9419, 'minut...         7845       away
# 3  [{'playerIn': 8140, 'playerOut': 25747, 'minut...         8093       away
# 4  [{'playerIn': 8135, 'playerOut': 7939, 'minute...        93112       away
#
#             away.teamName away.score  away.scoreHT  \
# 0         AFC Bournemouth          2             0
# 1    West Bromwich Albion          0             0
# 2                 Arsenal          1             1
# 3  Brighton & Hove Albion          0             0
# 4                 Watford          0             0
#
#                                away.formation.lineup  \
# 0  [{'playerId': 259531, 'ownGoals': '0', 'redCar...
# 1  [{'playerId': 25537, 'ownGoals': '0', 'redCard...
# 2  [{'playerId': 25867, 'ownGoals': '0', 'redCard...
# 3  [{'playerId': 120, 'ownGoals': '2', 'redCards'...
# 4  [{'playerId': 68085, 'ownGoals': '0', 'redCard...
#
#                         away.formation.substitutions home.numShots  \
# 0  [{'playerIn': 7989, 'playerOut': 259531, 'minu...             9
# 1  [{'playerIn': 261, 'playerOut': 25537, 'minute...            11
# 2  [{'playerIn': 7945, 'playerOut': 25867, 'minut...            18
# 3  [{'playerIn': 15526, 'playerOut': 120, 'minute...            21
# 4  [{'playerIn': 8889, 'playerOut': 68085, 'minut...             7
#
#    away.numShots
# 0             14
# 1              5
# 2              8
# 3              2
# 4              5
#
# [5 rows x 21 columns]

# %% [markdown]
# Dropping these columns for now. I will focus on adding features at the team and match level. I will add player level information later.

# %%
matches.drop(['home.formation.lineup', 'home.formation.substitutions','away.formation.lineup', 'away.formation.substitutions'],
             axis=1,
             inplace=True
            )

# %%
matches.drop(['home.coachId','away.coachId'],
             axis=1,
             inplace=True
            )

# %% [markdown]
# sorting matches by date

# %%
matches=matches.sort_values(by='dateutc').reset_index(drop=True)

# %%
matches.head()
# Out:
#    gameweek              dateutc                winner     wyId  \
# 0         1  2017-08-11 18:45:00               Arsenal  2499719
# 1         1  2017-08-12 11:30:00                   NaN  2499727
# 2         1  2017-08-12 14:00:00                   NaN  2499726
# 3         1  2017-08-12 14:00:00               Burnley  2499721
# 4         1  2017-08-12 14:00:00  West Bromwich Albion  2499728
#
#                                            label home.side  \
# 0                Arsenal - Leicester City, 4 - 3      home
# 1                     Watford - Liverpool, 3 - 3      home
# 2              Southampton - Swansea City, 0 - 0      home
# 3                       Chelsea - Burnley, 2 - 3      home
# 4  West Bromwich Albion - AFC Bournemouth, 1 - 0      home
#
#           home.teamName  home.score  home.scoreHT away.side    away.teamName  \
# 0               Arsenal           4             2      away   Leicester City
# 1               Watford           3             2      away        Liverpool
# 2           Southampton           0             0      away     Swansea City
# 3               Chelsea           2             0      away          Burnley
# 4  West Bromwich Albion           1             1      away  AFC Bournemouth
#
#    away.score  away.scoreHT  home.numShots  away.numShots
# 0           3             2             27              7
# 1           3             1              8             12
# 2           0             0             25              4
# 3           3             3             15              9
# 4           0             0             16              8

# %% [markdown]
# With the information I have now I might try build a basic ML model.
#
# * I can  measure what team is home or away
# * I can measure average points they have gained in the last 5 weeks
# * average points they have gained all season
# * their average shots in the last 5 games
# * how many goals they have scored or conceded in the last 5 games.
#
# This is all a drop in the ocean to the amount of data I can get. But I will start from here.

# %% [markdown]
# ## measuring average points

# %% [markdown]
# I believe the best way to get the average points is to get the running total from the events table (I just need to sum up the goals for each game to determin a winner, which should be straightforward)

# %%
events.head()
# Out:
#   subEventName  playerId  matchId eventName teamName matchPeriod   eventSec  \
# 0  Simple pass     25413  2499719      Pass  Arsenal          1H   2.758649
# 1    High pass    370224  2499719      Pass  Arsenal          1H   4.946850
# 2    Head pass      3319  2499719      Pass  Arsenal          1H   6.542188
# 3    Head pass    120339  2499719      Pass  Arsenal          1H   8.143395
# 4  Simple pass    167145  2499719      Pass  Arsenal          1H  10.302366
#
#    pos_orig_y  pos_orig_x  pos_dest_y  pos_dest_x       Label
# 0          49          49          78          31  [accurate]
# 1          78          31          75          51  [accurate]
# 2          75          51          71          35  [accurate]
# 3          71          35          95          41  [accurate]
# 4          95          41          88          72  [accurate]

# %%
events.groupby(['matchId','teamName']).agg(
    numShots=('subEventName', lambda x: (x == 'Shot').sum())
).reset_index()
# Out:
#      matchId                teamName  numShots
# 0    2499719                 Arsenal        27
# 1    2499719          Leicester City         7
# 2    2499720  Brighton & Hove Albion         6
# 3    2499720         Manchester City        12
# 4    2499721                 Burnley         9
# ..       ...                     ...       ...
# 755  2500096            Swansea City        24
# 756  2500097          Leicester City        17
# 757  2500097       Tottenham Hotspur        13
# 758  2500098                 Everton        13
# 759  2500098         West Ham United        14
#
# [760 rows x 3 columns]

# %% [markdown]
# I need to get all the rows that equate to a goal. and then aggregate by match and team.

# %%
events[events['Label'].apply(lambda x: ('Goal' in x) | ('own_goal' in x))]['eventName'].value_counts()
# Out:
# eventName
# Save attempt          1019
# Shot                   914
# Free Kick               74
# Others on the ball      27
# Pass                     2
# Name: count, dtype: int64

# %%
914+74+27+2
# Out:
# 1017

# %% [markdown]
# Weird. There were 1019 "Save attempts" that are associated with the "Goal" or "own_goal" tag.
#
# There are 1017 other events (Shot, Free Kick, Others on the ball, Pass) that are associated with the "Goal" or "own_goal" tag.
#
# However, by researching that season, I know that there were 1018 goals. So both are just 1 away from the correct result. I will locate the discrepency and try and explain it.

# %%
Save_attempt_goals=events[
    events['Label'].apply(lambda x: ('Goal' in x) | ('own_goal' in x))
    &
    (events['eventName'] == "Save attempt")
    ]

# %%
Other_goals=events[
    events['Label'].apply(lambda x: ('Goal' in x) | ('own_goal' in x))
    &
    (events['eventName'] != "Save attempt")
    ]

# %%
setA=set(Save_attempt_goals.groupby(['matchId'])['Label'].count().reset_index()['matchId'])

# %%
setB=set(Other_goals.groupby(['matchId'])['Label'].count().reset_index()['matchId'])

# %%
setA-setB
# Out:
# {2499781}

# %%
weirdmatch=events[events['matchId']==2499781]

# %%
weirdmatch[weirdmatch['Label'].apply(lambda x: ('Goal' in x) | ('own_goal' in x))]['eventName'].value_counts()
# Out:
# eventName
# Save attempt    1
# Name: count, dtype: int64

# %%
matches[matches['wyId']==2499781]
# Out:
#     gameweek              dateutc           winner     wyId  \
# 66         7  2017-09-30 16:30:00  Manchester City  2499781
#
#                                label home.side home.teamName  home.score  \
# 66  Chelsea - Manchester City, 0 - 1      home       Chelsea           0
#
#     home.scoreHT away.side    away.teamName  away.score  away.scoreHT  \
# 66             0      away  Manchester City           1             0
#
#     home.numShots  away.numShots
# 66              4             14

# %%
Save_attempt_goals
# Out:
#         subEventName  playerId  matchId     eventName         teamName  \
# 47          Reflexes      8480  2499719  Save attempt   Leicester City
# 92          Reflexes      7882  2499719  Save attempt          Arsenal
# 555         Reflexes      7882  2499719  Save attempt          Arsenal
# 899         Reflexes      8480  2499719  Save attempt   Leicester City
# 1108        Reflexes      7882  2499719  Save attempt          Arsenal
# ...              ...       ...      ...           ...              ...
# 641383      Reflexes     93084  2500097  Save attempt   Leicester City
# 642259      Reflexes     10131  2500098  Save attempt          Everton
# 642749  Save attempt     10131  2500098  Save attempt          Everton
# 642889      Reflexes      3582  2500098  Save attempt  West Ham United
# 643024      Reflexes     10131  2500098  Save attempt          Everton
#
#        matchPeriod     eventSec  pos_orig_y  pos_orig_x  pos_dest_y  \
# 47              1H    96.970614         100         100          59
# 92              1H   256.547834           0           0          48
# 555             1H  1712.908250           0           0          46
# 899             1H  2817.604704         100         100          50
# 1108            2H   636.247679           0           0          46
# ...            ...          ...         ...         ...         ...
# 641383          2H  1839.090016           0          71           0
# 642259          1H  2289.169397          17          57          27
# 642749          2H  1076.658523          16          58          13
# 642889          2H  1739.579587          61          62          74
# 643024          2H  2194.459825          11          66           1
#
#         pos_dest_x                      Label
# 47              12  [Goal, glb, not accurate]
# 92               4   [Goal, gt, not accurate]
# 555              6   [Goal, gc, not accurate]
# 899              8   [Goal, gc, not accurate]
# 1108             8  [Goal, glb, not accurate]
# ...            ...                        ...
# 641383          71   [Goal, gr, not accurate]
# 642259          43  [Goal, gbr, not accurate]
# 642749          65   [Goal, gc, not accurate]
# 642889          54   [Goal, gr, not accurate]
# 643024          59  [Goal, gtr, not accurate]
#
# [1019 rows x 12 columns]

# %%
table1=Save_attempt_goals.groupby(['matchId'])['Label'].count().reset_index()
table1
# Out:
#      matchId  Label
# 0    2499719      7
# 1    2499720      2
# 2    2499721      5
# 3    2499722      3
# 4    2499723      1
# ..       ...    ...
# 343  2500094      3
# 344  2500095      1
# 345  2500096      3
# 346  2500097      9
# 347  2500098      4
#
# [348 rows x 2 columns]

# %%
non_nil_matches=matches[~((matches['home.score']==0)
        & (matches['away.score']==0))
]

# %%
non_nil_matches=non_nil_matches.copy()

non_nil_matches['total_match_goals']=non_nil_matches['home.score']+non_nil_matches['away.score']

# %%
table2=non_nil_matches.groupby(['wyId'])['total_match_goals'].sum().reset_index()
table2
# Out:
#         wyId  total_match_goals
# 0    2499719                  7
# 1    2499720                  2
# 2    2499721                  5
# 3    2499722                  3
# 4    2499723                  1
# ..       ...                ...
# 343  2500094                  3
# 344  2500095                  1
# 345  2500096                  3
# 346  2500097                  9
# 347  2500098                  4
#
# [348 rows x 2 columns]

# %%
# Merge the tables on matchId and wyId columns
merged_df = table1.merge(table2, left_on='matchId', right_on='wyId', how='inner', suffixes=('_label', '_goals'))

# Filter rows where Label and total_match_goals are different
mismatched_rows = merged_df[merged_df['Label'] != merged_df['total_match_goals']]

# Display mismatched rows
mismatched_rows[['matchId', 'Label', 'total_match_goals']]
# Out:
#      matchId  Label  total_match_goals
# 246  2499988      3                  2

# %%
weirdmatch2=events[events['matchId']==2499988]

# %%
weirdmatch2[weirdmatch2['Label'].apply(lambda x: ('Goal' in x) | ('own_goal' in x))][['eventName','teamName']].value_counts()
# Out:
# eventName     teamName
# Save attempt  Watford            3
# Shot          West Ham United    2
# Name: count, dtype: int64

# %%
matches[matches['wyId']==2499988]
# Out:
#      gameweek              dateutc           winner     wyId  \
# 263        27  2018-02-10 15:00:00  West Ham United  2499988
#
#                                 label home.side    home.teamName  home.score  \
# 263  West Ham United - Watford, 2 - 0      home  West Ham United           2
#
#      home.scoreHT away.side away.teamName  away.score  away.scoreHT  \
# 263             1      away       Watford           0             0
#
#      home.numShots  away.numShots
# 263              7              8

# %% [markdown]
# ##### grouping by match and home team

# %%
numHomeGoals=matches.groupby(['dateutc','wyId','home.teamName'])['home.score'].first().reset_index()
numHomeGoals.rename(columns={'home.teamName':'teamName','home.score':'NumGoals'}, inplace=True)

# %% [markdown]
# ##### grouping by match and home team

# %%
numAwayGoals=matches.groupby(['dateutc','wyId','away.teamName'])['away.score'].first().reset_index()
numAwayGoals.rename(columns={'away.teamName':'teamName','away.score':'NumGoals'}, inplace=True)

# %%
allgoals=pd.concat([numHomeGoals,numAwayGoals],axis=0).sort_values(by="dateutc")

# %%
# Calculate cumulative mean excluding the current row's goals
allgoals['GoalsPerGame'] = allgoals.groupby('teamName')['NumGoals'].transform(
    lambda x: x.shift(1).cumsum() / x.shift(1).expanding().count()
)

# %%
# Calculate rolling mean over the last 5 rows excluding the current row's goals
allgoals['GoalsPerGame_last5'] = allgoals.groupby('teamName')['NumGoals'].transform(
    lambda x: x.shift(1).rolling(window=5, min_periods=1).mean()
)

# %%
matches=matches.merge(
    allgoals, 
    how='left', 
    left_on=['wyId','home.teamName'], 
    right_on=['wyId','teamName'],
    suffixes=('','_y')
).rename(columns={'GoalsPerGame':'home.GoalsPerGame', 'GoalsPerGame_last5':'home.GoalsPerGame_last5'})

matches.drop(['dateutc_y','teamName','NumGoals'], axis=1, inplace=True)

# %%
matches=matches.merge(
    allgoals, 
    how='left', 
    left_on=['wyId','away.teamName'], 
    right_on=['wyId','teamName'],
    suffixes=('','_y')
).rename(columns={'GoalsPerGame':'away.GoalsPerGame', 'GoalsPerGame_last5':'away.GoalsPerGame_last5'})

matches.drop(['dateutc_y','teamName','NumGoals'], axis=1, inplace=True)

# %%
matches.columns
# Out:
# Index(['gameweek', 'dateutc', 'winner', 'wyId', 'label', 'home.side',
#        'home.teamName', 'home.score', 'home.scoreHT', 'away.side',
#        'away.teamName', 'away.score', 'away.scoreHT', 'home.numShots',
#        'away.numShots', 'home.GoalsPerGame', 'home.GoalsPerGame_last5',
#        'away.GoalsPerGame', 'away.GoalsPerGame_last5'],
#       dtype='object')

# %% [markdown]
# ### Conceded

# %% [markdown]
# I also want to get the average goals conceded to date and the average goals conceded in the last 5 matches

# %%
numHomeConceded=matches.groupby(['dateutc','wyId','home.teamName'])['away.score'].first().reset_index()
numHomeConceded.rename(columns={'home.teamName':'teamName','away.score':'NumConceded'}, inplace=True)

# %%
numAwayConceded=matches.groupby(['dateutc','wyId','away.teamName'])['home.score'].first().reset_index()
numAwayConceded.rename(columns={'away.teamName':'teamName','home.score':'NumConceded'}, inplace=True)

# %%
allConceded=pd.concat([numHomeConceded,numAwayConceded],axis=0).sort_values(by="dateutc")

# %%
# Calculate cumulative mean excluding the current row's goals
allConceded['ConcededPerGame'] = allConceded.groupby('teamName')['NumConceded'].transform(
    lambda x: x.shift(1).cumsum() / x.shift(1).expanding().count()
)

# %%
# Calculate rolling mean over the last 5 rows excluding the current row's goals
allConceded['ConcededPerGame_last5'] = allConceded.groupby('teamName')['NumConceded'].transform(
    lambda x: x.shift(1).rolling(window=5, min_periods=1).mean()
)

# %%
allConceded
# Out:
#                  dateutc     wyId           teamName  NumConceded  \
# 0    2017-08-11 18:45:00  2499719            Arsenal            3
# 0    2017-08-11 18:45:00  2499719     Leicester City            4
# 1    2017-08-12 11:30:00  2499727            Watford            3
# 1    2017-08-12 11:30:00  2499727          Liverpool            3
# 2    2017-08-12 14:00:00  2499721            Chelsea            3
# ..                   ...      ...                ...          ...
# 372  2018-05-13 14:00:00  2500091  Huddersfield Town            1
# 371  2018-05-13 14:00:00  2500090     Crystal Palace            0
# 370  2018-05-13 14:00:00  2500089            Burnley            2
# 378  2018-05-13 14:00:00  2500097     Leicester City            5
# 379  2018-05-13 14:00:00  2500098            Everton            3
#
#      ConcededPerGame  ConcededPerGame_last5
# 0                NaN                    NaN
# 0                NaN                    NaN
# 1                NaN                    NaN
# 1                NaN                    NaN
# 2                NaN                    NaN
# ..               ...                    ...
# 372         1.540541                    0.8
# 371         1.486486                    1.0
# 370         1.000000                    1.8
# 378         1.486486                    2.0
# 379         1.486486                    0.4
#
# [760 rows x 6 columns]

# %%
matches=matches.merge(
    allConceded, 
    how='left', 
    left_on=['wyId','home.teamName'], 
    right_on=['wyId','teamName'],
    suffixes=('','_y')
).rename(columns={'ConcededPerGame':'home.ConcededPerGame', 'ConcededPerGame_last5':'home.ConcededPerGame_last5'})

matches.drop(['dateutc_y','teamName','NumConceded'], axis=1, inplace=True)

# %%
matches=matches.merge(
    allConceded, 
    how='left', 
    left_on=['wyId','away.teamName'], 
    right_on=['wyId','teamName'],
    suffixes=('','_y')
).rename(columns={'ConcededPerGame':'away.ConcededPerGame', 'ConcededPerGame_last5':'away.ConcededPerGame_last5'})

matches.drop(['dateutc_y','teamName','NumConceded'], axis=1, inplace=True)

# %%
matches.columns
# Out:
# Index(['gameweek', 'dateutc', 'winner', 'wyId', 'label', 'home.side',
#        'home.teamName', 'home.score', 'home.scoreHT', 'away.side',
#        'away.teamName', 'away.score', 'away.scoreHT', 'home.numShots',
#        'away.numShots', 'home.GoalsPerGame', 'home.GoalsPerGame_last5',
#        'away.GoalsPerGame', 'away.GoalsPerGame_last5', 'home.ConcededPerGame',
#        'home.ConcededPerGame_last5', 'away.ConcededPerGame',
#        'away.ConcededPerGame_last5'],
#       dtype='object')

# %%
temp=matches[['gameweek','winner','label','home.teamName','away.teamName', 'home.GoalsPerGame', 'home.GoalsPerGame_last5',
       'away.GoalsPerGame', 'away.GoalsPerGame_last5','home.ConcededPerGame',
       'home.ConcededPerGame_last5', 'away.ConcededPerGame',
       'away.ConcededPerGame_last5']]

# %%
temp[(temp['home.teamName']=='Arsenal')| (temp['away.teamName']=='Arsenal')].head(10)
# Out:
#     gameweek      winner                                    label  \
# 0          1     Arsenal          Arsenal - Leicester City, 4 - 3
# 16         2  Stoke City              Stoke City - Arsenal, 1 - 0
# 28         3   Liverpool               Liverpool - Arsenal, 4 - 0
# 35         4     Arsenal         Arsenal - AFC Bournemouth, 3 - 0
# 48         5         NaN                 Chelsea - Arsenal, 0 - 0
# 59         6     Arsenal    Arsenal - West Bromwich Albion, 2 - 0
# 67         7     Arsenal  Arsenal - Brighton & Hove Albion, 2 - 0
# 76         8     Watford                 Watford - Arsenal, 2 - 1
# 88         9     Arsenal                 Everton - Arsenal, 2 - 5
# 92        10     Arsenal            Arsenal - Swansea City, 2 - 1
#
#    home.teamName           away.teamName  home.GoalsPerGame  \
# 0        Arsenal          Leicester City                NaN
# 16    Stoke City                 Arsenal           0.000000
# 28     Liverpool                 Arsenal           2.000000
# 35       Arsenal         AFC Bournemouth           1.333333
# 48       Chelsea                 Arsenal           2.000000
# 59       Arsenal    West Bromwich Albion           1.400000
# 67       Arsenal  Brighton & Hove Albion           1.500000
# 76       Watford                 Arsenal           1.571429
# 88       Everton                 Arsenal           0.625000
# 92       Arsenal            Swansea City           1.888889
#
#     home.GoalsPerGame_last5  away.GoalsPerGame  away.GoalsPerGame_last5  \
# 0                       NaN                NaN                      NaN
# 16                 0.000000           4.000000                 4.000000
# 28                 2.000000           2.000000                 2.000000
# 35                 1.333333           0.333333                 0.333333
# 48                 2.000000           1.750000                 1.750000
# 59                 1.400000           0.800000                 0.800000
# 67                 1.000000           0.833333                 1.000000
# 76                 1.200000           1.571429                 1.400000
# 88                 0.600000           1.500000                 1.600000
# 92                 2.000000           0.666667                 0.800000
#
#     home.ConcededPerGame  home.ConcededPerGame_last5  away.ConcededPerGame  \
# 0                    NaN                         NaN                   NaN
# 16              1.000000                    1.000000              3.000000
# 28              1.500000                    1.500000              2.000000
# 35              2.666667                    2.666667              1.666667
# 48              1.250000                    1.250000              2.000000
# 59              1.600000                    1.600000              0.800000
# 67              1.333333                    1.000000              1.166667
# 76              1.714286                    1.800000              1.142857
# 88              1.625000                    2.000000              1.250000
# 92              1.333333                    0.800000              1.111111
#
#     away.ConcededPerGame_last5
# 0                          NaN
# 16                    3.000000
# 28                    2.000000
# 35                    1.666667
# 48                    2.000000
# 59                    0.800000
# 67                    1.000000
# 76                    0.800000
# 88                    0.400000
# 92                    1.000000
